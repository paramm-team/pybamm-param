# %%
import create_model
import numpy as np
import os
# Change simulation parameters here
temperature = 25  # in degC, valid values: 0, 10, 25
crate = 1         # valid values: 0.5, 1, 2
cell_selected = ["789"]   # select the cell to optimize
model=create_model.model_build(temperature, crate, cell_selected)

# %%
from scipy import optimize
x0 =np.array([5e-14,6.48e-7,20,2.85e3]) # Initial values of parameters
# Create bounds
#max_bound = np.array([ 2.06e-12, 2.18589831e-5,1000,2.85e6])
#min_bound = np.array([ 2.06e-16, 2.18589831e-9,0.1,2.85])

#bounds of the variables as (min,max) {This might need adjustment according to the optimization method.}
bounds = [(2.06e-16,2.06e-12),(2.18589831e-9,2.18589831e-5),(0.1,1000),(2.85, 2.85e6)] 


#model.fitness(x0) #initial value of the function

# %%
create_model.optimiser.differential_evolution(bounds=bounds)

# %%
def maplike_fun(func, iterable):
    # x.shape == (S, N), where S is the size of the population and N
    # is the number of parameters. This is where you'd call out from
    # Python to COMSOL, instead of the following line.
    return func(iterable.T)

# %%
from scipy import optimize
minimum=optimize.differential_evolution(model.fitness, bounds, x0=x0, workers=maplike_fun, polish=False, updating='deferred')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      39         try:
# ---> 40             return self._casadi_symbols[symbol.id]
#      41         except KeyError:
#
# KeyError: 1760763298908550057
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      39         try:
# ---> 40             return self._casadi_symbols[symbol.id]
#      41         except KeyError:
#
# KeyError: -8650585392073449578
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      39         try:
# ---> 40             return self._casadi_symbols[symbol.id]
#      41         except KeyError:
#
# KeyError: -3214434909571967145
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      39         try:
# ---> 40             return self._casadi_symbols[symbol.id]
#      41         except KeyError:
#
# KeyError: -8673056842170740121
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in _calculate_population_energies(self, population)
#     965         try:
# --> 966             calc_energies = list(self._mapwrapper(self.func,
#     967                                                   parameters_pop[0:nfevs]))
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/_lib/_util.py in __call__(self, func, iterable)
#     470         try:
# --> 471             return self._mapfunc(func, iterable)
#     472         except TypeError as e:
#
# /var/folders/gr/z6l2h7kd4136nf0xqdtls40w0000gn/T/ipykernel_48979/3967251984.py in maplike_fun(func, iterable)
#       4     # Python to COMSOL, instead of the following line.
# ----> 5     return func(iterable.T)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in __call__(self, x)
#    1345     def __call__(self, x):
# -> 1346         return self.f(x, *self.args)
#    1347
#
# ~/Downloads/Pybamm-main-3/create_model.py in fitness(self, x)
#     171         #Define the parameters with x[k]
# --> 172         self.simulation.solve(inputs={"Negative electrode diffusivity [m2.s-1]" : x[0],
#     173                                       "Negative electrode reaction coefficient": x[1],
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/simulation.py in solve(self, t_eval, solver, check_model, save_at_cycles, calc_esoh, starting_solution, initial_soc, **kwargs)
#     901                     npts = max(int(round(dt / exp_inputs["period"])) + 1, 2)
# --> 902                     step_solution = solver.step(
#     903                         current_solution,
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/solvers/base_solver.py in step(self, old_solution, model, dt, npts, external_variables, inputs, save)
#    1242
# -> 1243             self.set_up(model, ext_and_inputs)
#    1244             self.models_set_up.update(
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/solvers/base_solver.py in set_up(self, model, inputs, t_eval, ics_only)
#     528             # Process rhs, algebraic and event expressions
# --> 529             rhs, rhs_eval, jac_rhs, jacp_rhs = process(model.concatenated_rhs, "RHS")
#     530             algebraic, algebraic_eval, jac_algebraic, jacp_algebraic = process(
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/solvers/base_solver.py in process(func, name, use_jacobian)
#     319                 report(f"Converting {name} to CasADi")
# --> 320                 func = func.to_casadi(t_casadi, y_casadi, inputs=p_casadi)
#     321                 # Add sensitivity vectors to the rhs and algebraic equations
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/symbol.py in to_casadi(self, t, y, y_dot, inputs, casadi_symbols)
#     880         """
# --> 881         return pybamm.CasadiConverter(casadi_symbols).convert(self, t, y, y_dot, inputs)
#     882
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      43             inputs = inputs or {}
# ---> 44             casadi_symbol = self._convert(symbol, t, y, y_dot, inputs)
#      45             self._casadi_symbols[symbol.id] = casadi_symbol
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in _convert(self, symbol, t, y, y_dot, inputs)
#     180         elif isinstance(symbol, pybamm.Concatenation):
# --> 181             converted_children = [
#     182                 self.convert(child, t, y, y_dot, inputs) for child in symbol.children
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in <listcomp>(.0)
#     181             converted_children = [
# --> 182                 self.convert(child, t, y, y_dot, inputs) for child in symbol.children
#     183             ]
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      43             inputs = inputs or {}
# ---> 44             casadi_symbol = self._convert(symbol, t, y, y_dot, inputs)
#      45             self._casadi_symbols[symbol.id] = casadi_symbol
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in _convert(self, symbol, t, y, y_dot, inputs)
#      75             # process children
# ---> 76             converted_left = self.convert(left, t, y, y_dot, inputs)
#      77             converted_right = self.convert(right, t, y, y_dot, inputs)
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      43             inputs = inputs or {}
# ---> 44             casadi_symbol = self._convert(symbol, t, y, y_dot, inputs)
#      45             self._casadi_symbols[symbol.id] = casadi_symbol
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in _convert(self, symbol, t, y, y_dot, inputs)
#      76             converted_left = self.convert(left, t, y, y_dot, inputs)
# ---> 77             converted_right = self.convert(right, t, y, y_dot, inputs)
#      78
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in convert(self, symbol, t, y, y_dot, inputs)
#      43             inputs = inputs or {}
# ---> 44             casadi_symbol = self._convert(symbol, t, y, y_dot, inputs)
#      45             self._casadi_symbols[symbol.id] = casadi_symbol
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/operations/convert_to_casadi.py in _convert(self, symbol, t, y, y_dot, inputs)
#      60         ):
# ---> 61             return casadi.MX(symbol.evaluate(t, y, y_dot, inputs))
#      62
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/symbol.py in evaluate(self, t, y, y_dot, inputs, known_evals)
#     749         else:
# --> 750             return self._base_evaluate(t, y, y_dot, inputs)
#     751
#
# ~/Library/Python/3.9/lib/python/site-packages/pybamm/expression_tree/input_parameter.py in _base_evaluate(self, t, y, y_dot, inputs)
#      88         else:
# ---> 89             raise ValueError(
#      90                 "Input parameter '{}' was given an object of size '{}'".format(
#
# ValueError: Input parameter 'Negative electrode diffusivity [m2.s-1]' was given an object of size '60' but was expecting an object of size '1'.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /var/folders/gr/z6l2h7kd4136nf0xqdtls40w0000gn/T/ipykernel_48979/279374988.py in <module>
#       1 from scipy import optimize
# ----> 2 minimum=optimize.differential_evolution(model.fitness, bounds, x0=x0, workers=maplike_fun, polish=False, updating='deferred')
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0)
#     327                                      constraints=constraints,
#     328                                      x0=x0) as solver:
# --> 329         ret = solver.solve()
#     330
#     331     return ret
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in solve(self)
#     841             # only work out population energies for feasible solutions
#     842             self.population_energies[self.feasible] = (
# --> 843                 self._calculate_population_energies(
#     844                     self.population[self.feasible]))
#     845
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py in _calculate_population_energies(self, population)
#     970             # wrong number of arguments for _mapwrapper
#     971             # or wrong length returned from the mapper
# --> 972             raise RuntimeError(
#     973                 "The map-like callable must be of the form f(func, iterable), "
#     974                 "returning a sequence of numbers the same length as 'iterable'"
#
# RuntimeError: The map-like callable must be of the form f(func, iterable), returning a sequence of numbers the same length as 'iterable'

# %%
# %time # time the solver
from scipy import optimize
import multiprocessing as mp
pool = mp.Pool(4)
minimum = optimize.differential_evolution(model.fitness, bounds, x0=x0, workers=-1, updating='deferred')

# %%
minimum

# %%
#print("Initial function value: %s" %model.fitness(x0))

#print("Optimized function value: %s" %model.fitness(minimum.x))

#print("Optimized values are: %s" %minimum.x)

model.define_model(minimum.x)

model.model_plot()

# %%
import time
from scipy import optimize
print("start optimization")
start = time.process_time()
print(start)
minimum = optimize.differential_evolution(model.fitness, bounds, x0=x0, workers=-1, updating='deferred', polish=False)
end = time.process_time()
print(end)
print(end - start)
print("end optimization")
# Out:
# start optimization
# 13.931432
# 2022-06-08 23:01:57,187 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:01:57,362 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:07,473 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:07,580 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:14,074 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:14,242 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:46,037 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:46,199 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:57,712 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:02:57,837 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:21,059 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:21,241 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:44,220 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:44,387 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:47,702 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:47,876 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:50,764 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:50,896 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:54,962 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:03:55,080 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:26,473 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:26,603 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:28,566 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:28,695 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:42,848 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:42,964 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:44,519 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:04:44,653 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:00,702 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:00,855 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:11,757 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:11,897 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:17,582 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:17,708 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:53,412 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:53,544 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:55,400 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:05:55,617 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:06:10,929 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:06:11,106 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:06:35,617 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:06:35,765 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:06,362 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:06,532 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:38,700 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:38,862 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:45,223 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:45,373 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:56,088 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:07:56,234 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:14,349 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:14,485 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:19,945 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:20,064 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:43,351 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:43,508 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:48,809 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:48,934 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:49,161 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:08:49,283 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:36,630 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:36,769 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:43,847 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:44,026 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:45,535 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:45,700 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:47,657 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:47,814 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:52,812 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:09:52,964 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:10,941 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:11,076 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:11,696 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:11,838 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:28,315 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:28,454 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:58,525 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:10:58,590 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:02,831 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:02,984 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:08,584 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:08,724 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:10,415 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:10,612 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:13,259 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:13,325 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:14,084 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:14,208 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:19,822 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:11:19,998 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:01,780 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:01,953 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:30,152 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:30,271 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:31,452 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:31,538 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:33,324 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:33,495 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:36,426 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:36,571 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:37,125 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:37,256 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:40,839 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:41,009 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:43,460 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:43,576 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:45,746 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:45,911 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:45,947 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:46,071 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:47,079 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:47,170 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:47,333 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:47,442 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:48,478 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:48,600 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:49,474 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:49,643 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:50,791 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:50,917 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:50,954 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:51,056 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:59,260 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:12:59,395 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:00,478 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:00,644 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:04,734 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:04,899 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:06,526 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:06,576 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:06,642 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:06,775 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:07,077 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:07,193 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:07,730 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:07,856 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:08,485 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:08,622 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:09,924 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:09,977 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:15,068 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:15,172 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:22,892 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:22,947 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:23,089 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:23,236 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:24,000 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:24,208 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:24,792 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:25,017 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:26,710 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:26,827 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:27,773 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:27,913 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13:28,421 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-08 23:13
- [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:27,549 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:27,613 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:29,683 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:29,748 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:31,948 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:32,013 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:43,797 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:43,863 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:57,064 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:57,129 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:58,629 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:04:58,693 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:01,490 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:01,555 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:07,491 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:07,555 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:12,875 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:12,939 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:19,577 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:19,641 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:24,014 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:24,079 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:38,873 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:38,939 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:40,304 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:40,368 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:41,870 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:41,935 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:43,298 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:43,362 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:46,987 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:47,053 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:51,430 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:51,495 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:52,147 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:52,212 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:58,174 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:05:58,238 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:01,165 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:01,231 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:06,297 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:06,362 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:12,995 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:13,058 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:15,152 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:15,217 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:26,289 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:26,355 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:28,574 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:28,637 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:36,747 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:06:36,811 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:04,932 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:04,996 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:13,095 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:13,164 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:18,431 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:18,499 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:21,348 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:21,413 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:23,634 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:23,700 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:26,643 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:26,710 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:30,359 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:30,424 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:33,369 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:33,434 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:40,623 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:40,685 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:44,343 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:44,408 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:51,808 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:51,872 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:55,522 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:55,587 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:59,245 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:59,310 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:07:59,974 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:00,039 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:16,416 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:16,488 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:29,089 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:29,154 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:29,807 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:29,872 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:32,086 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:32,147 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:32,802 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:32,867 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:41,664 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:41,729 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:45,381 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:45,445 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:46,099 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:46,164 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:56,544 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:56,608 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:59,545 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:08:59,610 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:00,974 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:01,040 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:15,166 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:15,232 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:29,170 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:29,234 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:35,176 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:35,240 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:41,907 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:41,973 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:50,070 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:09:50,134 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:10:38,425 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:10:38,488 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:10:46,575 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:10:46,641 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:10:57,032 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:10:57,096 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:11:03,024 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:11:03,088 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:11:22,339 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:11:22,403 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:11:51,232 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:11:51,297 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:12:40,285 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:12:40,351 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:52,075 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:52,101 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:53,329 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:53,354 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:53,858 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:53,883 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:54,514 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:18:54,539 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:02,485 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:02,509 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:03,737 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:03,763 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:04,266 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:04,291 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:04,795 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 2022-06-09 00:19:04,821 - [WARNING] processed_variable.__call__(484): Calling variable outside interpolation range (returns 'nan')
# 3304.014176
# 2783.4768160000003
# end optimization

# %%
param_optimised=list(param_optimised)
for index,item in enumerate(param_optimised):
    #param_optimised.remove(item)
    if item == str('Negative electrode exchange-current density [A.m-2]'):
        param_optimised[index]= 'Negative electrode exchange-current density [A.m-2] : j0_neg'
        #param_optimised.add(item)
    else :
        param_optimised[index] = str(item) + str(' : "[input]"')
        #param_optimised.add(item)

# %%
param_optimised

# %%
for item in param_optimised:
    print(item)

# %%
str('Negative electrode exchange-current density [A.m-2]')

# %%
set(param_optimised)

# %%
import pybamm
pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Chen2020)
