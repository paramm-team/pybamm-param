# %%
import create_model
import numpy as np
import os
# Change simulation parameters here
temperature = 25  # in degC, valid values: 0, 10, 25
crate = 1         # valid values: 0.5, 1, 2
cell_selected = ["789"]   # select the cell to optimize

model=create_model.model_build(temperature,crate,cell_selected)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/gr/z6l2h7kd4136nf0xqdtls40w0000gn/T/ipykernel_7846/3399145253.py in <module>
#       7 cell_selected = ["789"]   # select the cell to optimize
#       8
# ----> 9 model=create_model.model_build(temperature,crate,cell_selected)
#
# ~/Downloads/Pybamm-main-3/create_model.py in __init__(self, temperature, crate, cell_selected)
#      44         )
#      45
# ---> 46         dataset = import_thermal_data(crate, temperature) #Import test data
#      47         data_conc = {"time": [], "voltage": [], "temperature": []}
#      48
#
# ~/Downloads/Pybamm-main-3/create_model.py in import_thermal_data(Crate, T)
#     342     for cell in cells:
#     343         filename = "Cell{}_{}C_".format(cell, Crate).replace(".", "p") + folder + ".csv"
# --> 344         imported_data = pd.read_csv(
#     345             os.path.join(root, "data", folder, filename),
#     346             skiprows=skiprows,
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/muhammedsogut/Downloads/data/25degC/Cell789_1C_25degC.csv'

# %%
x0 =np.array([5e-14,6.48e-7,20,2.85e3]) # Initial values of parameters
# Create bounds
#max_bound = np.array([ 2.06e-12, 2.18589831e-5,1000,2.85e6])
#min_bound = np.array([ 2.06e-16, 2.18589831e-9,0.1,2.85])

#bounds of the variables as (min,max) {This might need adjustment according to the optimization method.}
bounds = [(2.06e-16,2.06e-12),(2.18589831e-9,2.18589831e-5),(0.1,1000),(2.85, 2.85e6)] 


model.fitness(x0) #initial value of the function
# Out:
# array(0.01547922)

# %%
# %time # time the solver
from scipy import optimize
minimum = optimize.differential_evolution(model.fitness, bounds, x0=x0)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 2022-05-11 19:57:41,316 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 19:57:41,399 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 19:58:20,064 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 19:58:20,112 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 19:58:35,209 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 19:58:35,278 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:00:22,514 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:00:22,598 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:00:30,482 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:00:30,552 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:00:43,816 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:00:43,892 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:23,893 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:23,974 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:33,615 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:33,698 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:37,106 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:37,188 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:49,448 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:01:49,527 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:02:08,823 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:02:08,853 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:02:16,742 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:02:16,825 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:02:40,601 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:02:40,663 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:20,490 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:20,572 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:29,434 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:29,506 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:37,463 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:37,540 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:43,581 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:03:43,656 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:04:18,056 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:04:18,123 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:04:30,389 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20
- [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:23:59,216 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:08,997 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:09,072 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:14,484 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:14,557 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:20,791 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:20,861 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:25,388 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:25,459 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:34,479 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:34,552 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:35,390 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:35,459 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:42,522 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:24:42,592 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:07,984 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:08,059 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:12,397 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:12,472 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:20,481 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:20,561 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:32,186 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:32,269 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:34,901 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:34,973 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:40,329 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:40,405 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:47,591 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:47,669 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:52,935 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:53,006 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:58,452 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:25:58,527 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:00,272 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:00,345 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:07,421 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:07,490 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:34,497 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:34,569 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:40,860 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:40,938 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:41,747 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:26:41,823 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:01,631 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:01,701 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:03,425 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:03,504 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:07,890 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:07,962 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:10,584 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:10,663 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:36,910 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:27:36,988 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:28:59,437 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:28:59,513 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:29:34,622 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:29:34,693 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:33:41,567 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:33:41,645 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:44,333 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:44,360 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:45,883 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:45,910 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:46,538 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:46,570 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:47,202 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:47,237 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:52,680 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:52,764 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:54,478 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:54,545 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:55,403 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:55,484 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:56,295 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:39:56,370 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:10,639 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:10,672 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:12,185 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:12,214 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:12,857 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:12,882 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:13,519 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:13,546 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:18,828 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:18,904 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:20,734 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:20,799 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:21,611 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:21,691 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:22,514 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:22,588 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:27,916 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:27,983 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:29,713 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:29,787 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:30,605 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:30,691 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:31,620 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:31,704 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:55,013 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:55,044 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:56,604 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:56,631 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:57,260 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:57,285 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:57,917 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')
# 2022-05-11 20:40:57,942 - [WARNING] processed_variable.__call__(485): Calling variable outside interpolation range (returns 'nan')

# %%
minimum
# Out:
#      fun: 0.0012469419770843996
#      jac: array([8.29253063e+09, 2.88357582e+02, 3.31897722e-03, 1.05309204e-02])
#  message: 'Optimization terminated successfully.'
#     nfev: 3010
#      nit: 47
#  success: True
#        x: array([1.80070310e-14, 3.12379716e-07, 3.49239669e+01, 2.00713066e+03])

# %%
print("Initial function value: %s" %model.fitness(x0))

print("Optimized function value: %s" %model.fitness(minimum.x))

print("Optimized values are: %s" %minimum.x)

model.define_model(minimum.x)

model.model_plot()
# Out:
# Initial function value: 0.015479220866349931
# Optimized function value: 0.0012469419770843996
# Optimized values are: [1.80070310e-14 3.12379716e-07 3.49239669e+01 2.00713066e+03]

# %%
import os
os.path.dirname(os.path.dirname())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/gr/z6l2h7kd4136nf0xqdtls40w0000gn/T/ipykernel_7846/1501679113.py in <module>
#       1 import os
# ----> 2 os.path.dirname(os.path.dirname())
#
# TypeError: dirname() missing 1 required positional argument: 'p'
