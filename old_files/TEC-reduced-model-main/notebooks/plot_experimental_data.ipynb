# %% [markdown]
# # Plot experimental data
#
# In this notebook we load and plot the experimental data in `data/`. The data available is for three different temperatures (25 &deg;C, 10 &deg;C and 0 &deg;C) and four different C-rates (0.1C, 0.5C, 1C and 2C). For each combination of temperature and C-rate, four different cells were tested.
#
# To start, we import the relevant packages, including the functions in `process_experimental_data.py`.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tec_reduced_model.process_experimental_data import *

plt.style.use(['science','vibrant'])

plt.rcParams.update({
    "font.family": "sans-serif",
    "text.usetex": False,
    "font.size": 8,
    "axes.labelsize": 10,
})

# %% [markdown]
# Now we can specify for which temperature and C-rate we want to import the data

# %%
Crate = 1
T = 25
dataset = import_thermal_data(Crate, T)

# %% [markdown]
# The imported data set is a dictionary where the key corresponds to the cell number (defined for internal identification) and the value is a pandas framework:

# %%
dataset
# Out:
# {'789':        Step Status  Step Time [s]   Time [s]  Cycle  Cycle Level    Procedure  \
#  0         5    PAU          0.010      0.102      0            0  MSM_Rate_1C
#  1         5    PAU        120.046    120.138      0            0  MSM_Rate_1C
#  2         5    PAU        240.017    240.109      0            0  MSM_Rate_1C
#  3         5    PAU        360.147    360.239      0            0  MSM_Rate_1C
#  4         5    PAU        480.038    480.130      0            0  MSM_Rate_1C
#  ...     ...    ...            ...        ...    ...          ...          ...
#  47800    12    PAU       7199.096  54517.136      2            1  MSM_Rate_1C
#  47801    12    PAU       7200.030  54518.070      2            1  MSM_Rate_1C
#  47802    12    PAU       7200.030  54518.070      2            1  MSM_Rate_1C
#  47803  9999    STO          0.000  54518.103      0            0  MSM_Rate_1C
#  47804  9999    STO          0.000  54518.103      0            0  MSM_Rate_1C
#
#         Voltage [V]  Current [A]  AhAccu [Ah]  AhPrev [Ah]  WhAccu [Wh]  \
#  0          4.14331          0.0      0.00000      0.00000      0.00000
#  1          4.14342          0.0      0.00000      0.00000      0.00000
#  2          4.14342          0.0      0.00000      0.00000      0.00000
#  3          4.14342          0.0      0.00000      0.00000      0.00000
#  4          4.14342          0.0      0.00000      0.00000      0.00000
#  ...            ...          ...          ...          ...          ...
#  47800      3.10854          0.0     -4.71238      4.74297    -14.57162
#  47801      3.10854          0.0     -4.71238      4.74297    -14.57162
#  47802      3.10854          0.0     -4.71238      4.74297    -14.57162
#  47803      3.10854          0.0     -4.71238      4.74297    -14.57162
#  47804      3.10854          0.0     -4.71238      4.74297    -14.57162
#
#         Watt [W]  Temp Positive [degC]  Temp Cell [degC]  Temp Negative [degC]
#  0           0.0                  24.6              24.6                  24.6
#  1           0.0                  24.6              24.6                  24.6
#  2           0.0                  24.6              24.6                  24.6
#  3           0.0                  24.6              24.6                  24.6
#  4           0.0                  24.6              24.6                  24.6
#  ...         ...                   ...               ...                   ...
#  47800       0.0                  24.6              24.6                  24.6
#  47801       0.0                  24.6              24.6                  24.6
#  47802       0.0                  24.6              24.6                  24.6
#  47803       0.0                  24.6              24.6                  24.6
#  47804       0.0                  24.6              24.6                  24.6
#
#  [47805 rows x 16 columns],
#  '790':        Step Status  Step Time [s]   Time [s]  Cycle  Cycle Level    Procedure  \
#  0         5    PAU          0.014      0.238      0            0  MSM_Rate_1C
#  1         5    PAU        120.054    120.278      0            0  MSM_Rate_1C
#  2         5    PAU        240.151    240.375      0            0  MSM_Rate_1C
#  3         5    PAU        360.217    360.441      0            0  MSM_Rate_1C
#  4         5    PAU        480.049    480.273      0            0  MSM_Rate_1C
#  ...     ...    ...            ...        ...    ...          ...          ...
#  48098    12    PAU       7199.072  54811.603      2            1  MSM_Rate_1C
#  48099    12    PAU       7199.992  54812.523      2            1  MSM_Rate_1C
#  48100    12    PAU       7200.079  54812.610      2            1  MSM_Rate_1C
#  48101  9999    STO          0.000  54812.635      0            0  MSM_Rate_1C
#  48102  9999    STO          0.000  54812.635      0            0  MSM_Rate_1C
#
#         Voltage [V]  Current [A]  AhAccu [Ah]  AhPrev [Ah]  WhAccu [Wh]  \
#  0          4.14298          0.0      0.00000      0.00000      0.00000
#  1          4.14298          0.0      0.00000      0.00000      0.00000
#  2          4.14298          0.0      0.00000      0.00000      0.00000
#  3          4.14298          0.0      0.00000      0.00000      0.00000
#  4          4.14309          0.0      0.00000      0.00000      0.00000
#  ...            ...          ...          ...          ...          ...
#  48098      3.08430          0.0     -4.76813      4.80099    -14.72949
#  48099      3.08430          0.0     -4.76813      4.80099    -14.72949
#  48100      3.08430          0.0     -4.76813      4.80099    -14.72949
#  48101      3.08430          0.0     -4.76813      4.80099    -14.72949
#  48102      3.08430          0.0     -4.76813      4.80099    -14.72949
#
#         Watt [W]  Temp Cell [degC]
#  0           0.0              24.5
#  1           0.0              24.5
#  2           0.0              24.5
#  3           0.0              24.5
#  4           0.0              24.5
#  ...         ...               ...
#  48098       0.0              24.3
#  48099       0.0              24.3
#  48100       0.0              24.3
#  48101       0.0              24.3
#  48102       0.0              24.3
#
#  [48103 rows x 14 columns],
#  '791':        Step Status  Step Time [s]   Time [s]  Cycle  Cycle Level    Procedure  \
#  0         5    PAU          0.016      0.254      0            0  MSM_Rate_1C
#  1         5    PAU        120.110    120.348      0            0  MSM_Rate_1C
#  2         5    PAU        240.099    240.337      0            0  MSM_Rate_1C
#  3         5    PAU        360.181    360.419      0            0  MSM_Rate_1C
#  4         5    PAU        480.056    480.294      0            0  MSM_Rate_1C
#  ...     ...    ...            ...        ...    ...          ...          ...
#  48046    12    PAU       7199.076  54759.939      2            1  MSM_Rate_1C
#  48047    12    PAU       7200.061  54760.924      2            1  MSM_Rate_1C
#  48048    12    PAU       7200.061  54760.924      2            1  MSM_Rate_1C
#  48049  9999    STO          0.000  54760.954      0            0  MSM_Rate_1C
#  48050  9999    STO          0.000  54760.954      0            0  MSM_Rate_1C
#
#         Voltage [V]  Current [A]  AhAccu [Ah]  AhPrev [Ah]  WhAccu [Wh]  \
#  0          4.14282          0.0       0.0000      0.00000      0.00000
#  1          4.14282          0.0       0.0000      0.00000      0.00000
#  2          4.14282          0.0       0.0000      0.00000      0.00000
#  3          4.14271          0.0       0.0000      0.00000      0.00000
#  4          4.14271          0.0       0.0000      0.00000      0.00000
#  ...            ...          ...          ...          ...          ...
#  48046      3.07262          0.0      -4.7532      4.78759    -14.65354
#  48047      3.07262          0.0      -4.7532      4.78759    -14.65354
#  48048      3.07273          0.0      -4.7532      4.78759    -14.65354
#  48049      3.07262          0.0      -4.7532      4.78759    -14.65354
#  48050      3.07262          0.0      -4.7532      4.78759    -14.65354
#
#         Watt [W]  Temp Cell [degC]
#  0           0.0              24.5
#  1           0.0              24.5
#  2           0.0              24.5
#  3           0.0              24.5
#  4           0.0              24.5
#  ...         ...               ...
#  48046       0.0              24.3
#  48047       0.0              24.3
#  48048       0.0              24.3
#  48049       0.0              24.3
#  48050       0.0              24.3
#
#  [48051 rows x 14 columns],
#  '792':        Step Status  Step Time [s]   Time [s]  Cycle  Cycle Level    Procedure  \
#  0         5    PAU          0.015      0.278      0            0  MSM_Rate_1C
#  1         5    PAU        120.092    120.355      0            0  MSM_Rate_1C
#  2         5    PAU        240.161    240.424      0            0  MSM_Rate_1C
#  3         5    PAU        360.065    360.328      0            0  MSM_Rate_1C
#  4         5    PAU        480.171    480.434      0            0  MSM_Rate_1C
#  ...     ...    ...            ...        ...    ...          ...          ...
#  48100    12    PAU       7198.992  54813.064      2            1  MSM_Rate_1C
#  48101    12    PAU       7200.052  54814.124      2            1  MSM_Rate_1C
#  48102    12    PAU       7200.052  54814.124      2            1  MSM_Rate_1C
#  48103  9999    STO          0.000  54814.163      0            0  MSM_Rate_1C
#  48104  9999    STO          0.000  54814.163      0            0  MSM_Rate_1C
#
#         Voltage [V]  Current [A]  AhAccu [Ah]  AhPrev [Ah]  WhAccu [Wh]  \
#  0          4.14340          0.0      0.00000      0.00000      0.00000
#  1          4.14351          0.0      0.00000      0.00000      0.00000
#  2          4.14351          0.0      0.00000      0.00000      0.00000
#  3          4.14340          0.0      0.00000      0.00000      0.00000
#  4          4.14351          0.0      0.00000      0.00000      0.00000
#  ...            ...          ...          ...          ...          ...
#  48100      3.07428          0.0     -4.76912      4.80311    -14.72334
#  48101      3.07428          0.0     -4.76912      4.80311    -14.72334
#  48102      3.07428          0.0     -4.76912      4.80311    -14.72334
#  48103      3.07428          0.0     -4.76912      4.80311    -14.72334
#  48104      3.07428          0.0     -4.76912      4.80311    -14.72334
#
#         Watt [W]  Temp Cell [degC]
#  0           0.0              24.5
#  1           0.0              24.5
#  2           0.0              24.5
#  3           0.0              24.5
#  4           0.0              24.5
#  ...         ...               ...
#  48100       0.0              24.3
#  48101       0.0              24.3
#  48102       0.0              24.3
#  48103       0.0              24.3
#  48104       0.0              24.3
#
#  [48105 rows x 14 columns]}

# %% [markdown]
# We can now plot the data for voltage and temperature

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
for cell, data in dataset.items():
    axes[0].plot(
        data["Time [s]"],
        data["Voltage [V]"],
        label=cell,
    )
    axes[1].plot(
        data["Time [s]"],
        data["Temp Cell [degC]"],
        label=cell,
    )

axes[0].set_xlabel("Time (s)")
axes[0].set_ylabel("Voltage (V)")
axes[1].set_xlabel("Time (s)")
axes[1].set_ylabel("Cell temperature (°C)")
axes[1].legend()

# %% [markdown]
# Note that the data contains two discharge cycles. To get the indices of where the cycles start and end, we can use the method `get_idxs` (imported from `process_experimental_data`). The function takes two arguments `I_dch` and `I_ch` which are the discharge and charge currents, respectively. It then returns two numpy arrays: the first with the indices when discharge starts and the second with the indices when charge starts (or, equivalently, relaxation ends).
#
# Then, we can plot the first discharge cycle only using

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
for cell, data in dataset.items():
    idx_start, idx_end = get_idxs(data, Crate * 5, 5 / 3)
    if len(idx_end) == 1:
        idx_end = np.append(idx_end, len(data["Time [s]"]))
    axes[0].plot(
        data["Time [s]"][idx_start[0] : idx_end[1]]
        - data["Time [s]"][idx_start[0]],
        data["Voltage [V]"][idx_start[0] : idx_end[1]],
        label=cell,
    )
    axes[1].plot(
        data["Time [s]"][idx_start[0] : idx_end[1]]
        - data["Time [s]"][idx_start[0]],
        data["Temp Cell [degC]"][idx_start[0] : idx_end[1]],
        label=cell,
    )

axes[0].set_xlabel("Time (s)")
axes[0].set_ylabel("Voltage (V)")
axes[1].set_xlabel("Time (s)")
axes[1].set_ylabel("Cell temperature (°C)")
axes[1].legend()
